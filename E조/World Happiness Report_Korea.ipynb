# %% [markdown]
# # 1. 데이터 전처리

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
#import chart_studio
#import chart_studio.plotly as py
from plotly.offline import iplot
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_2015 = pd.read_csv('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2015.csv')
df_2016 = pd.read_csv('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2016.csv')
df_2017 = pd.read_csv('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2017.csv')
df_2018 = pd.read_csv('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2018.csv')
df_2019 = pd.read_csv('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2019.csv')
df_2020 = pd.read_excel('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2020.xls')
df_2021 = pd.read_excel('/content/drive/Othercomputers/내 PC/DEV/DSL/EDA/2021.xls')

# %%
# 사용할 column 선택
df_2015 = df_2015.loc[:, ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
                          'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']]
df_2016 = df_2016.loc[:, ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
                          'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']]
df_2017 = df_2017.loc[:, ['Country', 'Happiness.Rank', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
                          'Freedom', 'Generosity', 'Trust..Government.Corruption.', 'Dystopia.Residual']]
df_2018 = df_2018.loc[:, ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy',
                          'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
df_2019 = df_2019.loc[:, ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 
                          'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
df_2020 = df_2020.loc[:, ['Country name', 'Regional indicator', 'Ladder score', 'Explained by: Log GDP per capita', 'Explained by: Social support', 
                          'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 
                          'Explained by: Perceptions of corruption', 'Dystopia + residual']]
df_2021 = df_2021.loc[:, ['Country name', 'Regional indicator', 'Ladder score', 'Explained by: Log GDP per capita', 'Explained by: Social support', 
                          'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 
                          'Explained by: Perceptions of corruption', 'Dystopia + residual']]
                          
# column명 통일
df_2015.rename(columns={'Country':'Country', 
                        'Region':'Region', 
                        'Happiness Rank':'Happiness_Rank', 
                        'Happiness Score':'Happiness_Score',
                        'Economy (GDP per Capita)':'Economy', 
                        'Family':'Social_support', 
                        'Health (Life Expectancy)':'Health',
                        'Freedom':'Freedom', 
                        'Trust (Government Corruption)':'Trust', 
                        'Generosity':'Generosity',
                        'Dystopia Residual':'Dystopia_Residual'}, inplace=True)
df_2016.rename(columns={'Country':'Country', 
                        'Region':'Region', 
                        'Happiness Rank':'Happiness_Rank', 
                        'Happiness Score':'Happiness_Score',
                        'Economy (GDP per Capita)':'Economy', 
                        'Family':'Social_support', 
                        'Health (Life Expectancy)':'Health',
                        'Freedom':'Freedom', 
                        'Trust (Government Corruption)':'Trust', 
                        'Generosity':'Generosity',
                        'Dystopia Residual':'Dystopia_Residual'}, inplace=True)
df_2017.rename(columns={'Country':'Country', 
                        'Happiness.Rank':'Happiness_Rank', 
                        'Happiness.Score':'Happiness_Score',
                        'Economy..GDP.per.Capita.':'Economy', 
                        'Family':'Social_support', 
                        'Health..Life.Expectancy.':'Health',
                        'Freedom':'Freedom', 
                        'Trust..Government.Corruption.':'Trust', 
                        'Generosity':'Generosity',
                        'Dystopia.Residual':'Dystopia_Residual'}, inplace=True)
df_2018.rename(columns={'Country or region':'Country', 
                        'Overall rank':'Happiness_Rank', 
                        'Score':'Happiness_Score',
                        'GDP per capita':'Economy', 
                        'Social support':'Social_support', 
                        'Healthy life expectancy':'Health',
                        'Freedom to make life choices':'Freedom', 
                        'Perceptions of corruption':'Trust', 
                        'Generosity':'Generosity'}, inplace=True)
df_2019.rename(columns={'Country or region':'Country', 
                        'Overall rank':'Happiness_Rank', 
                        'Score':'Happiness_Score',
                        'GDP per capita':'Economy', 
                        'Social support':'Social_support', 
                        'Healthy life expectancy':'Health',
                        'Freedom to make life choices':'Freedom', 
                        'Perceptions of corruption':'Trust', 
                        'Generosity':'Generosity'}, inplace=True)
df_2020.rename(columns={'Country name':'Country', 
                        'Regional indicator':'Region',
                        'Ladder score':'Happiness_Score',
                        'Explained by: Log GDP per capita':'Economy', 
                        'Explained by: Social support':'Social_support', 
                        'Explained by: Healthy life expectancy':'Health',
                        'Explained by: Freedom to make life choices':'Freedom', 
                        'Explained by: Perceptions of corruption':'Trust', 
                        'Explained by: Generosity':'Generosity',
                        'Dystopia + residual':'Dystopia_Residual'}, inplace=True)
df_2021.rename(columns={'Country name':'Country', 
                        'Regional indicator':'Region',
                        'Ladder score':'Happiness_Score',
                        'Explained by: Log GDP per capita':'Economy', 
                        'Explained by: Social support':'Social_support', 
                        'Explained by: Healthy life expectancy':'Health',
                        'Explained by: Freedom to make life choices':'Freedom', 
                        'Explained by: Perceptions of corruption':'Trust', 
                        'Explained by: Generosity':'Generosity',
                        'Dystopia + residual':'Dystopia_Residual'}, inplace=True)

# Year column 추가
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019
df_2020['Year'] = 2020
df_2021['Year'] = 2021

# df_2020, df_2021에 Happiness_Rank column 추가
df_2020.sort_values("Happiness_Score", ascending=False, inplace=True)
df_2020['Happiness_Rank'] = list(df_2020.index)
df_2020['Happiness_Rank'] += 1

df_2021.sort_values("Happiness_Score", ascending=False, inplace=True)
df_2021['Happiness_Rank'] = list(df_2021.index)
df_2021['Happiness_Rank'] += 1

# 나라:지역 dictionary 생성
tmp_1 = df_2015[['Country','Region']] 
tmp_2 = df_2016[['Country','Region']]
tmp = pd.concat([tmp_1,tmp_2]).drop_duplicates() # 15년도와 16년도의 있는 나라와 지역이 서로 다르다
tmp.set_index('Country', inplace=True)
country_region = tmp.to_dict()

def match_region(df, tmp):
  for idx, cntry in enumerate(df['Country']):
    if cntry in tmp.index: # if the country is in the country_region dictionary
      df['Region'][idx] = country_region['Region'][cntry]
    else:
      df['Region'][idx] = np.nan #If the country is not in the dictionary, input NAN 

# Region 컬럼 생성
df_2017['Region'] = np.nan 
df_2018['Region'] = np.nan 
df_2019['Region'] = np.nan 

# # df_2017, df_2018, df_2019에 매칭되는 Region 입력
match_region(df_2017, tmp)
match_region(df_2018, tmp)
match_region(df_2019, tmp)

# df_2018, df_2019에 Dystopia_Residual column 추가
df_2018["Dystopia_Residual"] = df_2018["Happiness_Score"] - df_2018['Economy'] - df_2018['Social_support'] - df_2018['Health'] - df_2018['Freedom'] - df_2018['Trust'] - df_2018['Generosity']
df_2019["Dystopia_Residual"] = df_2019["Happiness_Score"] - df_2019['Economy'] - df_2019['Social_support'] - df_2019['Health'] - df_2019['Freedom'] - df_2019['Trust'] - df_2019['Generosity']

# 이름 수정 및 Region 추가
df_2017.iloc[32,0]='Taiwan'
df_2017.iloc[32,1]= 33
df_2017.iloc[32,11]='Eastern Asia'
df_2017.iloc[70,0]='Hong Kong'
df_2017.iloc[70,11]='Eastern Asia'

df_2018.iloc[37,0]='Trinidad and Tobago'
df_2018.iloc[37,1]='Latin America and Caribbean'
df_2018.iloc[57,0]='Cyprus'
df_2018.iloc[57,1]='Western Europe'

df_2019.iloc[38,0]='Trinidad and Tobago'
df_2019.iloc[38,1]='Latin America and Caribbean'
df_2019.iloc[63,0]='Cyprus'
df_2019.iloc[63,1]='Western Europe'
df_2019.iloc[83,0]='Macedonia'
df_2019.iloc[83,1]='Central and Eastern Europe'
df_2019.iloc[119,0]='Gambia'
df_2019.iloc[119,1]='Sub-Saharan Africa'

df_2020.iloc[24,0] = 'Taiwan'
df_2020.iloc[77,0] = 'Hong Kong'

df_2021.iloc[23,0] = 'Taiwan'
df_2021.iloc[76,0] = 'Hong Kong'

# 연도별 데이터 합치기
df_concat = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021], axis=0, sort = False)
df_concat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Country              Region  ... Dystopia_Residual  Year
# ...

# %%
df_concat.isnull().sum() # 2018년 United Arab Emirates의 Trust, Dystopia_Residual 결측값
# Out:
# Country              0
# Region               6
# Happiness_Rank       0
# Happiness_Score      0
# Economy              0
# Social_support       0
# Health               0
# Freedom              0
# Trust                1
# Generosity           0
# Dystopia_Residual    1
# Year                 0
# dtype: int64

# %% [markdown]
# # 2. 대한민국

# %%
# 한국 데이터
korea = df_concat[df_concat['Country'] == "South Korea"]
korea
# Out:
#         Country        Region  ... Dystopia_Residual  Year
# 46  South Korea  Eastern Asia  ...          2.219780  2015
# 57  South Korea  Eastern Asia  ...          2.350150  2016
# 54  South Korea  Eastern Asia  ...          1.880378  2017
# 56  South Korea  Eastern Asia  ...          1.980000  2018
# 53  South Korea  Eastern Asia  ...          1.949000  2019
# 60  South Korea     East Asia  ...          1.946757  2020
# 61  South Korea     East Asia  ...          2.261686  2021
#
# [7 rows x 12 columns]

# %%
# 전체 나라 연도별 평균 데이터
all_con = df_concat.groupby('Year').mean()
all_con
# Out:
#       Happiness_Score   Economy  ...  Generosity  Dystopia_Residual
# Year                             ...
# 2015         5.375734  0.846137  ...    0.237296           2.098977
# 2016         5.382185  0.953880  ...    0.242635           2.325807
# 2017         5.354019  0.984718  ...    0.246883           1.850238
# 2018         5.375917  0.891449  ...    0.181006           1.921703
# 2019         5.407096  0.905147  ...    0.184846           1.879872
# 2020         5.473240  0.868771  ...    0.189375           1.972317
# 2021         5.532832  0.977153  ...    0.178091           2.430343
#
# [7 rows x 8 columns]

# %% [markdown]
# ## 비교1. vs 모든 국가 평균

# %% [markdown]
# ### 등수, 점수

# %%
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("Korea's Happiness Rank","Korea's Happiness Score"))

fig.add_trace(
    go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,'Happiness_Rank'],line=dict(color='rgb(0,0,255)'), showlegend=False,), 
    row=1, col=1)
fig.update_layout(yaxis_range=[80,40])
fig.add_trace(
    go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,'Happiness_Score'],name='Korea Score',line=dict(color='rgb(0,0,255)')),
    row=1, col=2)
fig.add_trace(
    go.Scatter(x=all_con.index, y=all_con.loc[:,'Happiness_Score'],name='All Score',line=dict(color='rgb(255,0,0)')),
    row=1, col=2)
fig.update_layout(title_text="Korea vs All Countries",width=1300,showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 행복순위 : 7년 동안 하향 추세
# - 행복지수 : 모든 국가 평균은 최근에 상승 추세, 한국은 딱히 상승 경향성 X

# %% [markdown]
# ### 요소별

# %%
columns_to_look = ['Economy',	'Social_support',	'Health',	'Freedom',	'Trust',	'Generosity']

fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity"))

for i in range(2):
    for j in range(3):
      if(i+j==0):
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea',line=dict(color='rgb(0,0,255)')),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=all_con.index, y=all_con.loc[:,columns_to_look[3*i+j]],name='All',line=dict(color="rgb(255,0,0)")),
          row=i+1, col=j+1,
        )
      else:
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea',line=dict(color='rgb(0,0,255)'),showlegend=False),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=all_con.index, y=all_con.loc[:,columns_to_look[3*i+j]],name='All',line=dict(color="rgb(255,0,0)"),showlegend=False),
          row=i+1, col=j+1,
        )
      
      fig.update_yaxes(range = [0,1.5])
        

fig.update_layout(title_text="Korea vs All Countries",height=800,width=1300)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 모든 국가의 평균 추이와 비교했을 때, 여섯 가지 요소의 상승 하강 경향성 비슷
# - Economy / Health : 평균보다 높음
# - Freedom : 평균보다 낮음

# %% [markdown]
# ## 비교2. vs Western Europe (찬영님)

# %% [markdown]
# ## 비교3. vs 일본

# %%
japan = df_concat[df_concat['Country'] == "Japan"]
japan
# Out:
#    Country        Region Happiness_Rank  ...  Generosity  Dystopia_Residual  Year
# 45   Japan  Eastern Asia             46  ...    0.107050           1.684350  2015
# 52   Japan  Eastern Asia             53  ...    0.102240           1.805840  2016
# 50   Japan  Eastern Asia             51  ...    0.120573           1.363224  2017
# 53   Japan  Eastern Asia             54  ...    0.079000           1.389000  2018
# 57   Japan  Eastern Asia             58  ...    0.069000           1.398000  2019
# 61   Japan     East Asia             62  ...    0.035712           1.486200  2020
# 55   Japan     East Asia             56  ...    0.019543           2.048071  2021
#
# [7 rows x 12 columns]

# %% [markdown]
# ### 등수

# %%
fig = make_subplots(
    rows=1, cols=1)

fig.add_trace(
    go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,'Happiness_Rank'],name='Korea',line=dict(color='rgb(0,0,255)')),
    row=1, col=1)
fig.add_trace(
    go.Scatter(x=japan.loc[:,'Year'], y=japan.loc[:,'Happiness_Rank'],name='Japan',line=dict(color='rgb(100,200,100)')),
    row=1, col=1)
fig.update_layout(yaxis_range=[80,40],title_text="Korea vs Japan",width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 우리나라와 일본 등수 수준 비슷해서 분석

# %% [markdown]
# ### 요소별

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity"))

for i in range(2):
    for j in range(3):
      if(i+j==0):
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea',line=dict(color='rgb(0,0,255)')),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=japan.loc[:,'Year'], y=japan.loc[:,columns_to_look[3*i+j]],name='Japan',line=dict(color="rgb(100,200,100)")),
          row=i+1, col=j+1,
        )
      else:
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea'+' '+f'{columns_to_look[3*i+j]}',line=dict(color='rgb(0,0,255)'),showlegend=False),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=japan.loc[:,'Year'], y=japan.loc[:,columns_to_look[3*i+j]],name='Japan'+' '+f'{columns_to_look[3*i+j]}',line=dict(color="rgb(100,200,100)"),showlegend=False),
          row=i+1, col=j+1,
        )
      
      fig.update_yaxes(range = [0,1.5])
        

fig.update_layout(title_text="Korea vs Japan",height=800,width=1300)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - Economy / Health는 비슷
# - Generosity : 한국이 우위
# - Social support, Freedom, Trust : 일본이 우위

# %% [markdown]
# ## 상관관계 분석

# %% [markdown]
# ### 한국 상관관계

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of Korea')
mask=np.zeros_like(korea.corr(),dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=korea.corr(),mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

#plt.savefig('korea_correlation.png')

# %% [markdown]
# ### 전체 상관관계

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of All Countries')
mask=np.zeros_like(df_concat.corr(),dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=df_concat.corr(),mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

#plt.savefig('korea_correlation.png')

# %% [markdown]
# - 한국과 전체 나라 상관관계에서 가장 차이가 큰 요소 = Economy
# - 한국은 Economy와 행복지수가 꽤 큰 음의 상관관계 (-0.71)

# %% [markdown]
# ### 한국 경제력 vs 행복 점수

# %%
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("Korea's Happiness Score","Korea's Economy"))

fig.add_trace(
    go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,'Happiness_Score'],line=dict(color='rgb(0,0,255)')),
    row=1, col=1)
fig.add_trace(
    go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,'Economy'],line=dict(color='rgb(255,0,0)')),
    row=1, col=2)
fig.update_layout(height=400,width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 반대로 움직이는 경향 확인

# %% [markdown]
# ## 비교4. vs 경제력 부족 but 행복한 국가

# %% [markdown]
# ### 어떤 국가 있는지 확인
# - 기준: 7년 내내 한국보다 Economy 낮지만 행복순위 높은 나라

# %%
from_15_17 = set(df_2015.query('(Happiness_Rank < 47) and (Economy < 1.244610)').Country) & set(df_2016.query('(Happiness_Rank < 57) and (Economy < 1.359480)').Country) & set(df_2017.query('(Happiness_Rank < 55) and (Economy < 1.401678)').Country)
from_15_17
# Out:
# {'Argentina',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Czech Republic',
#  'El Salvador',
#  'Guatemala',
#  'Israel',
#  'Malta',
#  'Mexico',
#  'Panama',
#  'Slovakia',
#  'Spain',
#  'Thailand',
#  'Trinidad and Tobago',
#  'Uruguay',
#  'Uzbekistan'}

# %%
from_18_21 = set(df_2018.query('(index < 56) and (Economy < 1.266000)').Country) & set(df_2019.query('(index < 53) and (Economy < 1.301000)').Country) & set(df_2020.query('(index < 60) and (Economy < 1.245301)').Country) & set(df_2021.query('(index < 61) and (Economy < 1.402863)').Country)
from_18_21
# Out:
# {'Argentina',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Czech Republic',
#  'El Salvador',
#  'Guatemala',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Mexico',
#  'Nicaragua',
#  'Panama',
#  'Poland',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Thailand',
#  'Uruguay',
#  'Uzbekistan'}

# %%
happier_than_korea = from_15_17 & from_18_21
happier_than_korea
# Out:
# {'Argentina',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Czech Republic',
#  'El Salvador',
#  'Guatemala',
#  'Mexico',
#  'Panama',
#  'Slovakia',
#  'Spain',
#  'Thailand',
#  'Uruguay',
#  'Uzbekistan'}

# %% [markdown]
# - 15개국 확인

# %% [markdown]
# #### 시각화 1 (지도)

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

data = dict(type = 'choropleth', 
           locations = list(happier_than_korea),
           locationmode = 'country names', z=[1.4]*15)

layout = dict(title = 'Happier Than Korea',
              geo = dict(showframe = True,showcoastlines = True, projection =  dict(type = 'hammer')))

globe = go.Figure(data = [data], layout=layout)
iplot(globe)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### 시각화 2 (파이)

# %%
# 15개국
latin_wow = df_2015[df_2015['Country'].isin(happier_than_korea)].reset_index(drop=True)
latin_wow
# Out:
#            Country                       Region  ...  Dystopia_Residual  Year
# 0       Costa Rica  Latin America and Caribbean  ...            3.17728  2015
# 1           Mexico  Latin America and Caribbean  ...            3.60214  2015
# 2           Brazil  Latin America and Caribbean  ...            3.26001  2015
# 3           Panama  Latin America and Caribbean  ...            2.84848  2015
# 4            Chile  Latin America and Caribbean  ...            2.67585  2015
# 5        Argentina  Latin America and Caribbean  ...            2.83600  2015
# 6   Czech Republic   Central and Eastern Europe  ...            2.67782  2015
# 7          Uruguay  Latin America and Caribbean  ...            2.32142  2015
# 8         Colombia  Latin America and Caribbean  ...            2.85737  2015
# 9         Thailand            Southeastern Asia  ...            2.31945  2015
# 10           Spain               Western Europe  ...            2.12367  2015
# ...

# %%
latin_wow.Region.value_counts().index
# Out:
# Index(['Latin America and Caribbean', 'Central and Eastern Europe',
#        'Southeastern Asia', 'Western Europe'],
#       dtype='object')

# %%
colors = ['tomato', 'orange', 'gold', 'mediumaquamarine']

plt.figure(figsize = (10,10))
plt.pie(latin_wow.Region.value_counts().values, # main 부분
        labels=latin_wow.Region.value_counts().index, colors=colors,
        autopct='%1.1f%%')

plt.legend(latin_wow.Region.value_counts().index, bbox_to_anchor=(2, 0.5), fontsize=15) # 범례
plt.title('Poor But Happier', fontsize = 20)

plt.show()

# %% [markdown]
# - 라틴 아메리카 나라들이 유의미하게 많음! (15개국 중 10)<br>
# => 라틴 아메리카 지역에 대한 자세한 분석해보자

# %% [markdown]
# ### 요소별

# %% [markdown]
# - 이 나라들이 우리나라보다 (그것도 꾸준히) 행복할 수 있었던 이유?

# %%
why_happy = df_concat[df_concat['Country'].isin(happier_than_korea)].groupby('Year').mean()
why_happy
# Out:
#       Happiness_Score   Economy  ...  Generosity  Dystopia_Residual
# Year                             ...
# 2015         6.528533  0.989962  ...    0.219659           2.730723
# 2016         6.519133  1.099953  ...    0.215099           2.978000
# 2017         6.451200  1.139255  ...    0.215559           2.444442
# 2018         6.388200  1.027933  ...    0.146333           2.423467
# 2019         6.373733  1.053800  ...    0.144933           2.344000
# 2020         6.377967  1.001909  ...    0.150091           2.408611
# 2021         6.325713  1.116500  ...    0.147674           2.800379
#
# [7 rows x 8 columns]

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity"))

for i in range(2):
    for j in range(3):
      if(i+j==0):
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea',line=dict(color='rgb(0,0,255)')),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=why_happy.index, y=why_happy.loc[:,columns_to_look[3*i+j]],name='Happier',line=dict(color="rgb(165,42,42)")),
          row=i+1, col=j+1,
        )
      else:
        fig.add_trace(
          go.Scatter(x=korea.loc[:,'Year'], y=korea.loc[:,columns_to_look[3*i+j]],name='Korea',line=dict(color='rgb(0,0,255)'),showlegend=False),
          row=i+1, col=j+1,
        )
        fig.add_trace(
          go.Scatter(x=why_happy.index, y=why_happy.loc[:,columns_to_look[3*i+j]],name='All',line=dict(color="rgb(165,42,42)"),showlegend=False),
          row=i+1, col=j+1,
        )
      
      fig.update_yaxes(range = [0,1.5])
        

fig.update_layout(title_text="Korea vs Happier Countries",height=800,width=1300)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 우리나라가 7년 내내 넘지 못한 요소 = Social Support, Freedom, Dystopia_Residual
# - 사회적인 도움, 삶의 선택, 행복의 기대감 부족
