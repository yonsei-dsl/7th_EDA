# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from plotly.offline import iplot
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
os.chdir('/content/drive/MyDrive/DSL/기초세션/EDA project')

# %%
df_2015=pd.read_csv('2015.csv')
df_2016=pd.read_csv('2016.csv')
df_2017=pd.read_csv('2017.csv')
df_2018=pd.read_csv('2018.csv')
df_2019=pd.read_csv('2019.csv')
df_2020=pd.read_excel('2020.xls')
df_2021=pd.read_excel('2021.xls')

# %% [markdown]
# # 컬럼 통일하기

# %%
df_2015.columns=[each.replace(" ","_") for each in df_2015.columns]
df_2016.columns=[each.replace(" ","_") for each in df_2016.columns]
df_2017.columns=[each.replace("."," ") for each in df_2017.columns]
df_2017.columns=[each.replace(" ","_") for each in df_2017.columns]
df_2018.columns=[each.replace(" ","_") for each in df_2018.columns]
df_2019.columns=[each.replace(" ","_") for each in df_2019.columns]

# %%
df_2015.rename(columns = {'Economy_(GDP_per_Capita)' : 'Economy'}, inplace = True)
df_2015.rename(columns = {'Health_(Life_Expectancy)' : 'Health'}, inplace = True)
df_2015.rename(columns = {'Trust_(Government_Corruption)' : 'Trust'}, inplace = True)
df_2015.rename(columns = {'Family':'Social_support'}, inplace = True)
df_2015.rename(columns = {'Dystopia_Residual':'Residual'}, inplace=True)
df_2015.drop('Standard_Error', inplace=True, axis=1)

# %%
df_2016.rename(columns = {'Economy_(GDP_per_Capita)' : 'Economy'}, inplace = True)
df_2016.rename(columns = {'Health_(Life_Expectancy)' : 'Health'}, inplace = True)
df_2016.rename(columns = {'Trust_(Government_Corruption)' : 'Trust'}, inplace = True)
df_2016.rename(columns = {'Family':'Social_support'}, inplace = True)
df_2016.rename(columns = {'Dystopia_Residual':'Residual'}, inplace=True)
df_2016.drop('Lower_Confidence_Interval', inplace=True, axis=1)
df_2016.drop('Upper_Confidence_Interval', inplace=True, axis=1)

# %%
df_2017.rename(columns = {'Economy__GDP_per_Capita_' : 'Economy'}, inplace = True)
df_2017.rename(columns = {'Health__Life_Expectancy_' : 'Health'}, inplace = True)
df_2017.rename(columns = {'Trust__Government_Corruption_' : 'Trust'}, inplace = True)
df_2017.rename(columns = {'Family':'Social_support'}, inplace = True)
df_2017.rename(columns = {'Dystopia_Residual':'Residual'}, inplace=True)
df_2017.drop('Whisker_high', inplace=True, axis=1)
df_2017.drop('Whisker_low', inplace=True, axis=1)

# %%
df_2018.rename(columns = {'Overall_rank' : 'Happiness_Rank'}, inplace = True)
df_2018.rename(columns = {'Country_or_region' : 'Country'}, inplace = True)
df_2018.rename(columns = {'Score' : 'Happiness_Score'}, inplace = True)
df_2018.rename(columns = {'GDP_per_capita' : 'Economy'}, inplace = True)
df_2018.rename(columns = {'Healthy_life_expectancy' : 'Health'}, inplace = True)
df_2018.rename(columns = {'Freedom_to_make_life_choices' : 'Freedom'}, inplace = True)
df_2018.rename(columns = {'Perceptions_of_corruption' : 'Trust'}, inplace = True)

# %%
df_2019.rename(columns = {'Overall_rank' : 'Happiness_Rank'}, inplace = True)
df_2019.rename(columns = {'Country_or_region' : 'Country'}, inplace = True)
df_2019.rename(columns = {'Score' : 'Happiness_Score'}, inplace = True)
df_2019.rename(columns = {'GDP_per_capita' : 'Economy'}, inplace = True)
df_2019.rename(columns = {'Healthy_life_expectancy' : 'Health'}, inplace = True)
df_2019.rename(columns = {'Freedom_to_make_life_choices' : 'Freedom'}, inplace = True)
df_2019.rename(columns = {'Perceptions_of_corruption' : 'Trust'}, inplace = True)

# %%
df_2020.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption', 'Ladder score in Dystopia'],axis=1,inplace=True)
df_2020.rename(columns={'Country name':'Country','Regional indicator':'Region','Ladder score':'Happiness_Score','Explained by: Log GDP per capita':'Economy','Explained by: Social support':'Social_support','Explained by: Healthy life expectancy':'Health','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust','Explained by: Generosity':'Generosity','Dystopia + residual':'Residual'},inplace=True)

# %%
df_2021.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption', 'Ladder score in Dystopia'],axis=1,inplace=True)
df_2021.rename(columns={'Country name':'Country','Regional indicator':'Region','Ladder score':'Happiness_Score','Explained by: Log GDP per capita':'Economy','Explained by: Social support':'Social_support','Explained by: Healthy life expectancy':'Health','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust','Explained by: Generosity':'Generosity','Dystopia + residual':'Residual'},inplace=True)

# %%
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019
df_2020['Year'] = 2020
df_2021['Year'] = 2021

# %% [markdown]
# # 2017, 2018, 2019 데이터에 'Region'컬럼 추가 및 데이터 입력
# # 2020,2021 데이터에 'Happiness_Rank'컬럼 추가 및 데잍 입력

# %% [markdown]
# 'Region' 컬럼 추가

# %%
df_2017['Region']=None
df_2018['Region']=None
df_2019['Region']=None
df_2020['Happiness_Rank']=None
df_2021['Happiness_Rank']=None

# %% [markdown]
# 'Happiness_Rank'컬럼 추가

# %%
df_2020['Happiness_Rank']=None
df_2021['Happiness_Rank']=None

# %% [markdown]
# 컬럼 순서 통일

# %%
df_2017=df_2017.reindex(columns=['Country','Region','Happiness_Rank','Happiness_Score','Economy','Social_support','Health','Freedom','Trust','Generosity','Residual','Year'])
df_2018=df_2018.reindex(columns=['Country','Region','Happiness_Rank','Happiness_Score','Economy','Social_support','Health','Freedom','Trust','Generosity','Residual','Year'])
df_2019=df_2019.reindex(columns=['Country','Region','Happiness_Rank','Happiness_Score','Economy','Social_support','Health','Freedom','Trust','Generosity','Residual','Year'])
df_2020=df_2020.reindex(columns=['Country','Region','Happiness_Rank','Happiness_Score','Economy','Social_support','Health','Freedom','Trust','Generosity','Residual','Year'])
df_2021=df_2021.reindex(columns=['Country','Region','Happiness_Rank','Happiness_Score','Economy','Social_support','Health','Freedom','Trust','Generosity','Residual','Year'])

# %% [markdown]
# {나라:지역} dictionary 만들기

# %%
dic={}

# %%
for i in range(158):
    dic[f'{df_2015.iloc[i,0]}']=f'{df_2015.iloc[i,1]}'

# %%
for i in range(157):
    if df_2016.iloc[i,0] in dic:
        pass
    else:
        dic[f'{df_2016.iloc[i,0]}']=f'{df_2016.iloc[i,1]}'

# %% [markdown]
# Region 데이터 입력

# %%
for i in range(155):
    if df_2017.iloc[i,0] in dic:
        df_2017.iloc[i,1]=dic[df_2017.iloc[i,0]]

# %%
for i in range(156):
    if df_2018.iloc[i,0] in dic:
        df_2018.iloc[i,1]=dic[df_2018.iloc[i,0]]

# %%
for i in range(156):
    if df_2019.iloc[i,0] in dic:
        df_2019.iloc[i,1]=dic[df_2019.iloc[i,0]]

# %% [markdown]
# Happiness_Rank 데이터 입력

# %%
for i in range(len(df_2020)):
    df_2020.loc[i,'Happiness_Rank']=i+1

# %%
for i in range(len(df_2021)):
    df_2021.loc[i,'Happiness_Rank']=i+1

# %% [markdown]
# 이름 수정 및 Region 추가

# %%
df_2017.iloc[32,0]='Taiwan'
df_2017.iloc[32,1]='Eastern Asia'
df_2017.iloc[70,0]='Hong Kong'
df_2017.iloc[70,1]='Eastern Asia'

# %%
df_2018.iloc[37,0]='Trinidad and Tobago'
df_2018.iloc[37,1]='Latin America and Caribbean'
df_2018.iloc[57,0]='Cyprus'
df_2018.iloc[57,1]='Western Europe'

# %%
df_2019.iloc[38,0]='Trinidad and Tobago'
df_2019.iloc[38,1]='Latin America and Caribbean'
df_2019.iloc[63,0]='Cyprus'
df_2019.iloc[63,1]='Western Europe'
df_2019.iloc[83,0]='Macedonia'
df_2019.iloc[83,1]='Central and Eastern Europe'
df_2019.iloc[119,0]='Gambia'
df_2019.iloc[119,1]='Sub-Saharan Africa'

# %%
df_2020.iloc[24,0]='Taiwan'
df_2020.iloc[77,0]='Hong Kong'

# %%
df_2021.iloc[23,0]='Taiwan'
df_2021.iloc[76,0]='Hong Kong'

# %% [markdown]
# 2018,2019에 Residual 추가

# %%
for i in range(len(df_2018)):
    df_2018.iloc[i,10]=df_2018.iloc[i,3]-df_2018.iloc[i,4]-df_2018.iloc[i,5]-df_2018.iloc[i,6]-df_2018.iloc[i,7]-df_2018.iloc[i,8]-df_2018.iloc[i,9]

# %%
for i in range(len(df_2019)):
    df_2019.iloc[i,10]=df_2019.iloc[i,3]-df_2019.iloc[i,4]-df_2019.iloc[i,5]-df_2019.iloc[i,6]-df_2019.iloc[i,7]-df_2019.iloc[i,8]-df_2019.iloc[i,9]

# %% [markdown]
# 데이터 합치기

# %%
concat = pd.concat([df_2015,df_2016,df_2017, df_2018, df_2019,df_2020,df_2021], axis=0, sort = False)

# %%
concat
# Out:
#          Country              Region Happiness_Rank  ...  Generosity  Residual  Year
# 0    Switzerland      Western Europe              1  ...    0.296780  2.517380  2015
# 1        Iceland      Western Europe              2  ...    0.436300  2.702010  2015
# 2        Denmark      Western Europe              3  ...    0.341390  2.492040  2015
# 3         Norway      Western Europe              4  ...    0.346990  2.465310  2015
# 4         Canada       North America              5  ...    0.458110  2.451760  2015
# ..           ...                 ...            ...  ...         ...       ...   ...
# 144      Lesotho  Sub-Saharan Africa            145  ...    0.102819  1.799821  2021
# 145     Botswana  Sub-Saharan Africa            146  ...    0.027394  0.648460  2021
# 146       Rwanda  Sub-Saharan Africa            147  ...    0.227457  1.095149  2021
# 147     Zimbabwe  Sub-Saharan Africa            148  ...    0.157088  1.204845  2021
# ...

# %% [markdown]
# region들의 이름 파악

# %% [markdown]
# 'Southeastern Asia'->'Southeast Asia'
#
# 'Southern Asia'->'South Asia'
#
# 'Commonwealth of Independent States'->'Central and Eastern Europe'
#
# 'Middle East and Northern Africa'->'Middle East and North Africa'
#
# 'Eastern Asia'->'East Asia'
#
# 'North America and ANZ'-> 'Australia and New Zealand' or 'North America'

# %%
concat.replace('Southeastern Asia','Southeast Asia',inplace=True)
concat.replace('Commonwealth of Independent States','Central and Eastern Europe',inplace=True)
concat.replace('Middle East and Northern Africa','Middle East and North Africa',inplace=True)
concat.replace('Eastern Asia','East Asia',inplace=True)
concat.replace('Southern Asia','South Asia',inplace=True)

# %%
concat.reset_index(drop=True,inplace=True)

# %%
concat[concat['Region']=='North America and ANZ']
# Out:
#            Country                 Region  ...  Residual  Year
# 789    New Zealand  North America and ANZ  ...  2.128108  2020
# 792         Canada  North America and ANZ  ...  2.195269  2020
# 793      Australia  North America and ANZ  ...  2.129804  2020
# 799  United States  North America and ANZ  ...  2.344125  2020
# 943    New Zealand  North America and ANZ  ...  2.611801  2021
# 945      Australia  North America and ANZ  ...  2.597857  2021
# 948         Canada  North America and ANZ  ...  2.585432  2021
# 953  United States  North America and ANZ  ...  2.807297  2021
#
# [8 rows x 12 columns]

# %%
for i in [789,793,943,945]:
    concat.iloc[i,1]='Australia and New Zealand'

# %%
for i in [792,799,948,953]:
    concat.iloc[i,1]='North America'

# %%
regions=list(set(concat['Region']))
regions
# Out:
# ['Australia and New Zealand',
#  'Sub-Saharan Africa',
#  'Central and Eastern Europe',
#  'North America',
#  'Middle East and North Africa',
#  'Western Europe',
#  'Latin America and Caribbean',
#  'East Asia',
#  'Southeast Asia',
#  'South Asia']

# %%
columns_to_look = ['Economy','Social_support','Health','Freedom','Trust','Generosity','Residual']

# %%
sns.heatmap(concat.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title("World", fontsize=14);

# %% [markdown]
# # 각 지역별 행복점수와 다른 지수간의 상관관계 비교

# %% [markdown]
#  ## 1. East Asia(동아시아)

# %%
EA=concat.loc[concat['Region']=='East Asia',:]
EA
# Out:
#           Country     Region  Happiness_Rank  ...  Generosity  Residual  Year
# 37         Taiwan  East Asia              38  ...    0.253760  2.323230  2015
# 45          Japan  East Asia              46  ...    0.107050  1.684350  2015
# 46    South Korea  East Asia              47  ...    0.185570  2.219780  2015
# 71      Hong Kong  East Asia              72  ...    0.394780  0.654290  2015
# 83          China  East Asia              84  ...    0.081850  1.860400  2015
# 99       Mongolia  East Asia             100  ...    0.332300  1.347590  2015
# 192        Taiwan  East Asia              34  ...    0.254950  2.615230  2016
# 210         Japan  East Asia              53  ...    0.102240  1.805840  2016
# 215   South Korea  East Asia              57  ...    0.188240  2.350150  2016
# 232     Hong Kong  East Asia              75  ...    0.400970  0.926140  2016
# 240         China  East Asia              83  ...    0.049590  2.170870  2016
# ...

# %%
sns.heatmap(EA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title("East Asia", fontsize=14);


#Economy,Health과 상관관계가 높다

# %% [markdown]
#  ## 2. Southeast Asia(동남아시아)

# %%
SEA=concat.loc[concat['Region']=='Southeast Asia',:]
SEA
# Out:
#         Country          Region  Happiness_Rank  ...  Generosity  Residual  Year
# 23    Singapore  Southeast Asia              24  ...    0.311050  1.885010  2015
# 33     Thailand  Southeast Asia              34  ...    0.576300  2.319450  2015
# 60     Malaysia  Southeast Asia              61  ...    0.330750  1.885410  2015
# 73    Indonesia  Southeast Asia              74  ...    0.515350  1.863990  2015
# 74      Vietnam  Southeast Asia              75  ...    0.168600  2.201730  2015
# ...         ...             ...             ...  ...         ...       ...   ...
# 1015   Malaysia  Southeast Asia              81  ...    0.269709  1.784125  2021
# 1016  Indonesia  Southeast Asia              82  ...    0.541250  1.986965  2021
# 1034       Laos  Southeast Asia             100  ...    0.268305  2.203569  2021
# 1048   Cambodia  Southeast Asia             114  ...    0.210122  2.148314  2021
# 1060    Myanmar  Southeast Asia             126  ...    0.519930  1.407031  2021
#
# ...

# %%
sns.heatmap(SEA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title("SouthEast Asia", fontsize=14);

#Economy,Health과 상관관계가 높다

# %% [markdown]
# ## 3. South Asia(남아시아)

# %%
SA=concat.loc[concat['Region']=='South Asia',:]
SA
# Out:
#           Country      Region  Happiness_Rank  ...  Generosity  Residual  Year
# 78         Bhutan  South Asia              79  ...    0.479980  1.637940  2015
# 80       Pakistan  South Asia              81  ...    0.336710  3.107090  2015
# 108    Bangladesh  South Asia             109  ...    0.212220  2.517670  2015
# 116         India  South Asia             117  ...    0.264750  2.275130  2015
# 120         Nepal  South Asia             121  ...    0.322960  1.956370  2015
# 131     Sri Lanka  South Asia             132  ...    0.408280  0.671080  2015
# 152   Afghanistan  South Asia             153  ...    0.365100  1.952100  2015
# 241        Bhutan  South Asia              84  ...    0.485460  1.829160  2016
# 249      Pakistan  South Asia              92  ...    0.311850  3.182860  2016
# 264         Nepal  South Asia             107  ...    0.381600  2.326940  2016
# 267    Bangladesh  South Asia             110  ...    0.191320  2.609040  2016
# ...

# %%
sns.heatmap(SA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title("South Asia", fontsize=14);

#Trust 상관관계가 높다

# %% [markdown]
# ## 4. Middle East and Northern Africa(중동,북아프리카)

# %%
MENA=concat.loc[concat['Region']=='Middle East and North Africa',:]
MENA
# Out:
#                       Country                        Region  ...  Residual  Year
# 10                     Israel  Middle East and North Africa  ...  3.088540  2015
# 19       United Arab Emirates  Middle East and North Africa  ...  2.247430  2015
# 21                       Oman  Middle East and North Africa  ...  2.474890  2015
# 27                      Qatar  Middle East and North Africa  ...  1.556740  2015
# 34               Saudi Arabia  Middle East and North Africa  ...  2.438720  2015
# ...                       ...                           ...  ...       ...   ...
# 1057                  Lebanon  Middle East and North Africa  ...  1.735721  2021
# 1059  Palestinian Territories  Middle East and North Africa  ...  2.131009  2021
# 1061                   Jordan  Middle East and North Africa  ...  1.552751  2021
# 1066                    Egypt  Middle East and North Africa  ...  1.647939  2021
# 1075                    Yemen  Middle East and North Africa  ...  1.775873  2021
#
# ...

# %%
sns.heatmap(MENA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title("Middle East and North Africa", fontsize=14);

#Economy, Freedom과 상관관계가 높다

# %% [markdown]
# ## 5. Sub-Saharan Africa(사하라 아프리카)

# %%
SSA=concat.loc[concat['Region']=='Sub-Saharan Africa',:]
SSA
# Out:
#                 Country              Region  ...  Residual  Year
# 70            Mauritius  Sub-Saharan Africa  ...  1.761450  2015
# 77              Nigeria  Sub-Saharan Africa  ...  2.893190  2015
# 84               Zambia  Sub-Saharan Africa  ...  2.634300  2015
# 90    Somaliland region  Sub-Saharan Africa  ...  2.110320  2015
# 93           Mozambique  Sub-Saharan Africa  ...  3.051370  2015
# ...                 ...                 ...  ...       ...   ...
# 1078             Malawi  Sub-Saharan Africa  ...  2.190198  2021
# 1079            Lesotho  Sub-Saharan Africa  ...  1.799821  2021
# 1080           Botswana  Sub-Saharan Africa  ...  0.648460  2021
# 1081             Rwanda  Sub-Saharan Africa  ...  1.095149  2021
# 1082           Zimbabwe  Sub-Saharan Africa  ...  1.204845  2021
#
# [271 rows x 12 columns]

# %%
sns.heatmap(SSA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('Sub-Saharan Africa', fontsize=14);

#두드러지는 상관관계는 보이지 않음 그나마 Family가 상관관계 높음

# %% [markdown]
# ## 6. Latin America and Caribbean(라틴 아메리카)

# %%
LAC=concat.loc[concat['Region']=='Latin America and Caribbean',:]
LAC
# Out:
#                  Country                       Region  ...  Residual  Year
# 11            Costa Rica  Latin America and Caribbean  ...  3.177280  2015
# 13                Mexico  Latin America and Caribbean  ...  3.602140  2015
# 15                Brazil  Latin America and Caribbean  ...  3.260010  2015
# 22             Venezuela  Latin America and Caribbean  ...  3.191310  2015
# 24                Panama  Latin America and Caribbean  ...  2.848480  2015
# ...                  ...                          ...  ...       ...   ...
# 1003             Bolivia  Latin America and Caribbean  ...  2.804988  2021
# 1005            Paraguay  Latin America and Caribbean  ...  2.305725  2021
# 1007  Dominican Republic  Latin America and Caribbean  ...  2.178197  2021
# 1041           Venezuela  Latin America and Caribbean  ...  2.135182  2021
# 1077               Haiti  Latin America and Caribbean  ...  2.060448  2021
#
# [152 rows x 12 columns]

# %%
sns.heatmap(LAC.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('Latin America and Caribbean', fontsize=14);

#Economy,Health,Freedom과 상관관계가 높다

# %% [markdown]
# ## 7. North America(북아메리카)

# %%
NA=concat.loc[concat['Region']=='North America',:]
NA
# Out:
#            Country         Region  Happiness_Rank  ...  Generosity  Residual  Year
# 4           Canada  North America               5  ...    0.458110  2.451760  2015
# 14   United States  North America              15  ...    0.401050  2.510110  2015
# 163         Canada  North America               6  ...    0.448340  2.704850  2016
# 170  United States  North America              13  ...    0.410770  2.727820  2016
# 321         Canada  North America               7  ...    0.435540  2.187264  2017
# 328  United States  North America              14  ...    0.392579  2.218113  2017
# 476         Canada  North America               7  ...    0.321000  2.305000  2018
# 487  United States  North America              18  ...    0.291000  2.227000  2018
# 634         Canada  North America               9  ...    0.285000  2.192000  2019
# 644  United States  North America              19  ...    0.280000  2.266000  2019
# ...

# %%
sns.heatmap(NA.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('North America', fontsize=14);

#Trust, Freedom과 상관관계가 높다 
#흥미로운점은 경제가 오히려 역의 상관관계를 가진다. 나라가 미국과 캐나다 두개 밖에 없기 때문에 데이터의 양이 부족해서 나온 오류일 수 있음

# %% [markdown]
# ## 8. Central and Eastern Europe(중앙,동유럽)

# %%
CEE=concat.loc[concat['Region']=='Central and Eastern Europe',:]
CEE
# Out:
#               Country                      Region  ...  Residual  Year
# 30     Czech Republic  Central and Eastern Europe  ...  2.677820  2015
# 43         Uzbekistan  Central and Eastern Europe  ...  2.237410  2015
# 44           Slovakia  Central and Eastern Europe  ...  2.246390  2015
# 51            Moldova  Central and Eastern Europe  ...  3.107120  2015
# 53         Kazakhstan  Central and Eastern Europe  ...  2.247290  2015
# ...               ...                         ...  ...       ...   ...
# 1027          Albania  Central and Eastern Europe  ...  2.250219  2021
# 1028  North Macedonia  Central and Eastern Europe  ...  2.042292  2021
# 1031     Turkmenistan  Central and Eastern Europe  ...  1.408566  2021
# 1042          Georgia  Central and Eastern Europe  ...  2.191350  2021
# 1044          Ukraine  Central and Eastern Europe  ...  1.813108  2021
#
# [203 rows x 12 columns]

# %%
sns.heatmap(CEE.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('Central and Eastern Europe', fontsize=14);

#Family, Freedom과 상관관계가 높다

# %% [markdown]
# ## 9. Western Europe(서유럽)

# %%
WE=concat.loc[concat['Region']=='Western Europe',:]
WE
# Out:
#            Country          Region  Happiness_Rank  ...  Generosity  Residual  Year
# 0      Switzerland  Western Europe               1  ...    0.296780  2.517380  2015
# 1          Iceland  Western Europe               2  ...    0.436300  2.702010  2015
# 2          Denmark  Western Europe               3  ...    0.341390  2.492040  2015
# 3           Norway  Western Europe               4  ...    0.346990  2.465310  2015
# 5          Finland  Western Europe               6  ...    0.233510  2.619550  2015
# ...            ...             ...             ...  ...         ...       ...   ...
# 962          Italy  Western Europe              28  ...    0.133027  2.793570  2021
# 973         Cyprus  Western Europe              39  ...    0.178244  2.577945  2021
# 992       Portugal  Western Europe              58  ...    0.028546  2.225222  2021
# 1002        Greece  Western Europe              68  ...    0.000000  2.560984  2021
# ...

# %%
sns.heatmap(WE.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('Western Europe', fontsize=14);

# Trust, Freedom과 상관관계가 높다

# %% [markdown]
# ## 10. Australia and New Zealand(오스트레일리아,뉴질랜드)

# %%
ANZ=concat.loc[concat['Region']=='Australia and New Zealand',:]
ANZ
# Out:
#          Country                     Region  ...  Residual  Year
# 8    New Zealand  Australia and New Zealand  ...  2.264250  2015
# 9      Australia  Australia and New Zealand  ...  2.266460  2015
# 165  New Zealand  Australia and New Zealand  ...  2.475530  2016
# 166    Australia  Australia and New Zealand  ...  2.546500  2016
# 322  New Zealand  Australia and New Zealand  ...  2.046456  2017
# 324    Australia  Australia and New Zealand  ...  2.065211  2017
# 477  New Zealand  Australia and New Zealand  ...  2.156000  2018
# 479    Australia  Australia and New Zealand  ...  2.139000  2018
# 633  New Zealand  Australia and New Zealand  ...  2.126000  2019
# 636    Australia  Australia and New Zealand  ...  2.093000  2019
# 789  New Zealand  Australia and New Zealand  ...  2.128108  2020
# 793    Australia  Australia and New Zealand  ...  2.129804  2020
# 943  New Zealand  Australia and New Zealand  ...  2.611801  2021
# ...

# %%
sns.heatmap(ANZ.corr(), annot=True, fmt=".2f", cmap="Purples", linewidths=1)
plt.title('Australia and New Zealand', fontsize=14);

#Trust와 상관관계가 높다
#역시나 흥미롭게 Health와 역의 상관관게가 나왔는데 North America의 경우와 비슷하게 나라가 두개 밖에 없다보니 생긴 오류인 것 같음

# %% [markdown]
# 지역별 높은 상관관계 지수를 딕셔너리로 저장

# %%
region_correlation={}
region_correlation['Eastern Asia']=['Economy','Health']
region_correlation['Southeastern Asia']=['Economy','Health']
region_correlation['Southern Asia']=['Trust']
region_correlation['Middle East and Northern Africa']=['Economy','Freedom']
region_correlation['Sub-Saharan Africa']=['Family']
region_correlation['Latin America and Caribbean']=['Economy','Health','Freedom']
region_correlation['North America']=['Trust','Freedom']
region_correlation['Central and Eastern Europe']=['Family','Freedom']
region_correlation['Western Europe']=['Trust','Freedom']
region_correlation['Australia and New Zealand']=['Trust']
region_correlation
# Out:
# {'Australia and New Zealand': ['Trust'],
#  'Central and Eastern Europe': ['Family', 'Freedom'],
#  'Eastern Asia': ['Economy', 'Health'],
#  'Latin America and Caribbean': ['Economy', 'Health', 'Freedom'],
#  'Middle East and Northern Africa': ['Economy', 'Freedom'],
#  'North America': ['Trust', 'Freedom'],
#  'Southeastern Asia': ['Economy', 'Health'],
#  'Southern Asia': ['Trust'],
#  'Sub-Saharan Africa': ['Family'],
#  'Western Europe': ['Trust', 'Freedom']}

# %% [markdown]
# # 시각화 자료

# %% [markdown]
# ## 베네수엘라

# %%
Venezuela=concat[concat['Country']=='Venezuela']
Venezuela
# Out:
#         Country                       Region  ...  Residual  Year
# 22    Venezuela  Latin America and Caribbean  ...  3.191310  2015
# 201   Venezuela  Latin America and Caribbean  ...  2.974680  2016
# 396   Venezuela  Latin America and Caribbean  ...  1.789464  2017
# 571   Venezuela  Latin America and Caribbean  ...  1.443000  2018
# 733   Venezuela  Latin America and Caribbean  ...  1.250000  2019
# 880   Venezuela  Latin America and Caribbean  ...  1.744841  2020
# 1041  Venezuela  Latin America and Caribbean  ...  2.135182  2021
#
# [7 rows x 12 columns]

# %% [markdown]
# ### 베네수엘라 상관계수

# %%
corr_Venezuela=Venezuela.corr()

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of Venezuela')
mask=np.zeros_like(corr_Venezuela,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=corr_Venezuela,mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

# %% [markdown]
# ### 베네수엘라 랭킹

# %%
fig=px.line(Venezuela,x='Year',y='Happiness_Rank',title="Venezuela's Happiness_Rank")
fig.update_layout(yaxis_range=(110,20),width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16ffdc00-d6c3-466b-bdbb-099fc53b4a85" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16ffdc00-d6c3-466b-bdbb-099fc53b4a85")) {
#                     Plotly.newPlot(
#                         '16ffdc00-d6c3-466b-bdbb-099fc53b4a85',
# ...

# %% [markdown]
# ### 베네수엘라 인덱스

# %%
fig = go.Figure()
for i in range(7):
    fig.add_trace(go.Scatter(x=Venezuela.loc[:,'Year'], y=Venezuela.loc[:,columns_to_look[i]],
                 name=columns_to_look[i]))
        
fig.update_layout(title_text="Venezuela's Various Index",width=1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4706579-707b-4501-9905-435fd2c89eaa" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4706579-707b-4501-9905-435fd2c89eaa")) {
#                     Plotly.newPlot(
#                         'a4706579-707b-4501-9905-435fd2c89eaa',
# ...

# %%
fig = make_subplots(
    rows=2, cols=4,
    subplot_titles=("Venezuela's Economy","Venezuela's Social_support","Venezuela's Health","Venezuela's Freedom","Venezuela's Trust","Venezuela's Generosity","Venezuela's Residual"))

for i in range(2):
    for j in range(4):
        try:
            fig.add_trace(
                go.Scatter(x=Venezuela.loc[:,'Year'], y=Venezuela.loc[:,columns_to_look[4*i+j]],name=f'{columns_to_look[4*i+j]}'),
                row=i+1, col=j+1
            )
        except:
            pass
fig.update_layout(title_text="Venezuelas's Various Index",width=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4d8af90-f5db-4be3-945b-849eb778b27e" class="plotly-graph-div" style="height:525px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4d8af90-f5db-4be3-945b-849eb778b27e")) {
#                     Plotly.newPlot(
#                         'f4d8af90-f5db-4be3-945b-849eb778b27e',
# ...

# %% [markdown]
# ## 라틴아메리카

# %%
LAC=concat[concat['Region']=='Latin America and Caribbean']
LAC.drop([22,201,396,571,733,880,1041],inplace=True)
LACpivot=LAC.pivot_table(index='Year',aggfunc='mean')
LACpivot.reset_index(inplace=True)
LACpivot
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Year   Economy   Freedom  ...  Residual  Social_support     Trust
# 0  2015  0.868843  0.505200  ...  2.595495        1.097519  0.117480
# 1  2016  0.987312  0.436567  ...  2.850922        0.892580  0.107015
# 2  2017  1.001197  0.463280  ...  2.326331        1.283433  0.088872
# 3  2018  0.896810  0.523238  ...  2.379286        1.328952  0.078190
# 4  2019  0.922500  0.455250  ...  2.269550        1.335350  0.073300
# 5  2020  0.876079  0.532732  ...  2.336564        1.265423  0.087699
# 6  2021  0.960901  0.561452  ...  2.764423        0.846367  0.094751
#
# [7 rows x 10 columns]

# %% [markdown]
# ### 라틴 아메리카 상관계수

# %%
corr_LAC=LAC.corr()

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of Latin America')
mask=np.zeros_like(corr_LAC,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=corr_LAC,mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

# %% [markdown]
# ### 라틴 아메리카 vs 베네수엘라 랭킹

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,'Happiness_Rank'],
                 name='Latin America'))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=Venezuela.loc[:,'Happiness_Rank'],
                 name='Venezuela'))
fig.update_layout(yaxis_range=(110,20),width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="83c9cf3f-112a-4af2-9eb8-8957a8de6a7a" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83c9cf3f-112a-4af2-9eb8-8957a8de6a7a")) {
#                     Plotly.newPlot(
#                         '83c9cf3f-112a-4af2-9eb8-8957a8de6a7a',
# ...

# %% [markdown]
# ### 라틴 아메리카 인덱스

# %%
fig = go.Figure()
for i in range(7):
    fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[i]],
                 name=columns_to_look[i]))
        
fig.update_layout(title_text="Latin America's Various Index",width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d97e0b7-ed98-4a79-bb3d-3cc3a7ae6d7a" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d97e0b7-ed98-4a79-bb3d-3cc3a7ae6d7a")) {
#                     Plotly.newPlot(
#                         '4d97e0b7-ed98-4a79-bb3d-3cc3a7ae6d7a',
# ...

# %%
fig = make_subplots(
    rows=2, cols=4,
    subplot_titles=("Latin America's Economy","Latin America's Social_support","Latin America's Health","Latin America's Freedom","Latin America's Trust","Latin America's Generosity","Latin America's Residual"))

for i in range(2):
    for j in range(4):
        try:
            fig.add_trace(
                go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[4*i+j]],name=f'{columns_to_look[4*i+j]}'),
                row=i+1, col=j+1
            )
        except:
            pass

fig.update_layout(title_text="Latin America's Various Index",width=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="24c5fa06-27a9-4f2c-98bd-187a259af0a7" class="plotly-graph-div" style="height:525px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24c5fa06-27a9-4f2c-98bd-187a259af0a7")) {
#                     Plotly.newPlot(
#                         '24c5fa06-27a9-4f2c-98bd-187a259af0a7',
# ...

# %% [markdown]
# ### 베네수엘라 vs 라틴 아메리카

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity"))

try:
    for i in range(2):
        for j in range(3):
            if 3*i+j==6:
                break
            else:
                fig.add_trace(
                    go.Scatter(x=Venezuela.loc[:,'Year'], y=Venezuela.loc[:,columns_to_look[3*i+j]],line=dict(color="rgb(255,200,0)"),showlegend=False),
                    row=i+1, col=j+1,
                    )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)

                fig.add_trace(
                    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[3*i+j]],line=dict(color="rgb(255,0,0)"),showlegend=False),
                    row=i+1, col=j+1,
                    )
                fig.update_yaxes( 
                    range=[0, 1.6], 
                    row=i+1, col=j+1)
except:
    pass

fig.add_trace(
    go.Scatter(x=Venezuela.loc[:,'Year'], y=Venezuela.loc[:,columns_to_look[5]],name='Venezuela',line=dict(color="rgb(255,200,0)")),
    row=2, col=3,
    )
fig.update_yaxes(
    range=[0, 1.6], 
    row=2, col=3)

fig.add_trace(
    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[5]],name='Latin America',line=dict(color="rgb(255,0,0)")),
    row=2, col=3,
    )
fig.update_yaxes( 
    range=[0, 1.6], 
    row=2, col=3)


fig.update_layout(title_text="Venezuela vs Latin America",width=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a5ab13af-2d20-41ae-8bd3-88bfe1154d48" class="plotly-graph-div" style="height:525px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5ab13af-2d20-41ae-8bd3-88bfe1154d48")) {
#                     Plotly.newPlot(
#                         'a5ab13af-2d20-41ae-8bd3-88bfe1154d48',
# ...

# %% [markdown]
# 베네수엘라 vs라틴 아메리카 Trust

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,'Trust'],
                 name='Latin America',
                 line=dict(color="rgb(255,0,0)")))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=Venezuela.loc[:,'Trust'],
                 name='Venezuela',
                 line=dict(color="rgb(255,200,0)")))
fig.update_layout(width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="979946fe-347e-4721-ad83-34e0ad82bc26" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("979946fe-347e-4721-ad83-34e0ad82bc26")) {
#                     Plotly.newPlot(
#                         '979946fe-347e-4721-ad83-34e0ad82bc26',
# ...

# %%
#베네수엘라는 Trust,Freedom,Economy와 상관성이 높다
#라틴아메리카는 Economy,Freedom,Health 와 상관성이 높다

#라틴아메리카와 베네수엘라 모두 Trust가 하락했지만 영향을 많이 받는 베네수엘라가 더 떨어짐
#베네수엘라의 Freedom,Economy가 많이 떨어짐->그래서 Residual이 떨어진듯
#그래서 라틴은 랭킹이 유지 but 베네수엘라는 급격한 하락

# %% [markdown]
# ## 대한민국

# %%
Korea=concat[concat['Country']=='South Korea']
Korea
# Out:
#          Country     Region  Happiness_Rank  ...  Generosity  Residual  Year
# 46   South Korea  East Asia              47  ...    0.185570  2.219780  2015
# 215  South Korea  East Asia              57  ...    0.188240  2.350150  2016
# 369  South Korea  East Asia              55  ...    0.206674  1.880378  2017
# 526  South Korea  East Asia              57  ...    0.175000  1.980000  2018
# 679  South Korea  East Asia              54  ...    0.175000  1.949000  2019
# 842  South Korea  East Asia              61  ...    0.170304  1.946757  2020
# 996  South Korea  East Asia              62  ...    0.133676  2.261686  2021
#
# [7 rows x 12 columns]

# %% [markdown]
# ### 대한민국 상관계수

# %%
corr_Korea=Korea.corr()

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of Korea')
mask=np.zeros_like(corr_Korea,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=corr_Korea,mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

# %% [markdown]
# ### 한국 vs 라틴아메리카 경제,랭킹

# %%
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("Economy","Rank"))


fig.add_trace(
    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,'Economy'],showlegend=False,line=dict(color='rgb(0,0,255)')),
    row=1, col=1)
fig.add_trace(
    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,'Economy'],showlegend=False,line=dict(color='rgb(255,0,0)')),
    row=1, col=1)
fig.add_trace(
    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,'Happiness_Rank'],name='Korea',line=dict(color='rgb(0,0,255)')),
    row=1, col=2)
fig.add_trace(
    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,'Happiness_Rank'],name='Latin America',line=dict(color='rgb(255,0,0)')),
    row=1, col=2)
fig.update_yaxes(range=[70, 40], row=1, col=2)

fig.update_layout(title_text="Korea vs Latin America",width=1500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4519d75-b570-41d9-8d1c-6c202fb986fb" class="plotly-graph-div" style="height:525px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4519d75-b570-41d9-8d1c-6c202fb986fb")) {
#                     Plotly.newPlot(
#                         'f4519d75-b570-41d9-8d1c-6c202fb986fb',
# ...

# %% [markdown]
# ### 한국 vs 라틴아메리카

# %%
fig = make_subplots(
    rows=2, cols=4,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity","Residual"))

try:
    for i in range(2):
        for j in range(4):
            if 4*i+j==6:
                break
            else:
                fig.add_trace(
                    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,columns_to_look[4*i+j]],showlegend=False,line=dict(color="rgb(0,0,255)")),
                    row=i+1, col=j+1,
                )
                fig.update_yaxes(
                    range=[0, 3], 
                    row=i+1, col=j+1)
                fig.add_trace(
                    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[4*i+j]],showlegend=False,line=dict(color="rgb(255,0,0)")),
                    row=i+1, col=j+1,
                )
                fig.update_yaxes(
                    range=[0, 3], 
                    row=i+1, col=j+1)
except:
    pass

fig.add_trace(
    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,columns_to_look[6]],name='Korea',line=dict(color="rgb(0,0,255)")),
    row=2, col=3,
    )
fig.update_yaxes(
    range=[0, 3], 
    row=2, col=3)

fig.add_trace(
    go.Scatter(x=LACpivot.loc[:,'Year'], y=LACpivot.loc[:,columns_to_look[6]],name='Latin America',line=dict(color="rgb(255,0,0)")),
    row=2, col=3,
    )
fig.update_yaxes( 
    range=[0, 3], 
    row=2, col=3)

fig.update_layout(title_text="Korea vs Latin America",width=1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6db4c64b-7f05-44da-ab1e-eb2ba15a9c95" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6db4c64b-7f05-44da-ab1e-eb2ba15a9c95")) {
#                     Plotly.newPlot(
#                         '6db4c64b-7f05-44da-ab1e-eb2ba15a9c95',
# ...

# %%
# 한국은Economy와 Health가 라틴아메리카보다 높다 그러나 Freedom이 작다
# 한국은 Residual과 Freedom 사이의 상관관계가 높아 Freedom점수가 낮아 Residual이 낮은 것으로 보임
# 그래서 한국이 라틴 아메리카 보다 점수가 낮음

# %% [markdown]
# ## 서유럽

# %% [markdown]
# ### 전체 지역 랭킹

# %%
Rank_dic={}
for i in list(set(concat.loc[:,'Region'])):
    X=concat[concat['Region']==i]
    X=X.pivot_table(index='Year',aggfunc='mean')
    X.reset_index(inplace=True)
    Rank_dic[i]=list(X.loc[:,'Happiness_Rank'])

# %%
fig = go.Figure()
for i in range(10):
    fig.add_trace(go.Scatter(x=[2015,2016,2017,2018,2019,2020,2021], y=Rank_dic[list(set(concat.loc[:,'Region']))[i]],
                 name=list(set(concat.loc[:,'Region']))[i]))

fig.update_yaxes(range=[140, 0])
fig.update_layout(title_text="Region Ranking",width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c3a97b66-dbe5-4e80-9ffb-141a78910ded" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3a97b66-dbe5-4e80-9ffb-141a78910ded")) {
#                     Plotly.newPlot(
#                         'c3a97b66-dbe5-4e80-9ffb-141a78910ded',
# ...

# %%
#북아메리카와 호주뉴질랜드는 나라가 각각 2개 밖에 없음 그러므로 서유럽이 평균 순위가 가장 높다고 볼 수 있음

# %% [markdown]
# ### 서유럽 상관계수

# %%
WEurope=concat[concat['Region']=='Western Europe']

# %%
corr_WEurope=WEurope.corr()

# %%
plt.figure(figsize=(7,7))
plt.title('Correlation of Western Europe')
mask=np.zeros_like(corr_WEurope,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=corr_WEurope,mask=mask,annot=True,fmt='.2f',linewidths=.5,cbar_kws={"shrink": .5},cmap='Purples');

# %% [markdown]
# ### 서유럽 vs 중위권

# %%
WEurope=WEurope.pivot_table(index='Year',aggfunc='mean')
WEurope.reset_index(inplace=True)

EAsia=concat[concat['Region']=='East Asia']
EAsia=EAsia.pivot_table(index='Year',aggfunc='mean')
EAsia.reset_index(inplace=True)

CEEurope=concat[concat['Region']=='Central and Eastern Europe']
CEEurope=CEEurope.pivot_table(index='Year',aggfunc='mean')
CEEurope.reset_index(inplace=True)

SEAsia=concat[concat['Region']=='Southeast Asia']
SEAsia=SEAsia.pivot_table(index='Year',aggfunc='mean')
SEAsia.reset_index(inplace=True)

MENAfrica=concat[concat['Region']=='Middle East and North Africa']
MENAfrica=MENAfrica.pivot_table(index='Year',aggfunc='mean')
MENAfrica.reset_index(inplace=True)

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity","Residual"))


for i in range(2):
    for j in range(3):
        if 3*i+j==6:
            break
        else:
            try:
                fig.add_trace(
                    go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(224,34,120)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)
                                
                fig.add_trace(
                    go.Scatter(x=EAsia.loc[:,'Year'], y=EAsia.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)
                                
                fig.add_trace(
                    go.Scatter(x=CEEurope.loc[:,'Year'], y=CEEurope.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)
                                
                fig.add_trace(
                    go.Scatter(x=SEAsia.loc[:,'Year'], y=SEAsia.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)
                                
                fig.add_trace(
                    go.Scatter(x=MENAfrica.loc[:,'Year'], y=MENAfrica.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1,
                )
                fig.update_yaxes(
                    range=[0, 1.6], 
                    row=i+1, col=j+1)                
            except:
                pass
fig.add_trace(
    go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[5]],name='Western Europe',line=dict(color="rgb(224,34,120)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=EAsia.loc[:,'Year'], y=EAsia.loc[:,columns_to_look[5]],showlegend=False,line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=CEEurope.loc[:,'Year'], y=CEEurope.loc[:,columns_to_look[5]],showlegend=False,line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=SEAsia.loc[:,'Year'], y=SEAsia.loc[:,columns_to_look[5]],showlegend=False,line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=MENAfrica.loc[:,'Year'], y=MENAfrica.loc[:,columns_to_look[5]],name='Middle Rank Region',line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)


fig.update_layout(title_text="Western Europe vs Middle Rank Region",width=1200,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6930f6c9-8c86-496f-9911-51eb20ee9bf1" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6930f6c9-8c86-496f-9911-51eb20ee9bf1")) {
#                     Plotly.newPlot(
#                         '6930f6c9-8c86-496f-9911-51eb20ee9bf1',
# ...

# %% [markdown]
# 서유럽 vs 중위권 Trust

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=WEurope.loc[:,'Trust'],
                 name='WEstern Europe',
                 line=dict(color="rgb(224,34,120)")))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=EAsia.loc[:,'Trust'],
                 name='Middle Rank Region',
                 line=dict(color="rgb(125,125,125)")))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=CEEurope.loc[:,'Trust'],
                 showlegend=False,
                 line=dict(color="rgb(125,125,125)")))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=SEAsia.loc[:,'Trust'],
                 showlegend=False,
                 line=dict(color="rgb(125,125,125)")))
fig.add_trace(go.Scatter(x=LACpivot.loc[:,'Year'], y=MENAfrica.loc[:,'Trust'],
                 showlegend=False,
                 line=dict(color="rgb(125,125,125)")))

fig.update_layout(title='Trust' ,width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd04ebff-b501-4502-9e34-e21ec2d38d77" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd04ebff-b501-4502-9e34-e21ec2d38d77")) {
#                     Plotly.newPlot(
#                         'dd04ebff-b501-4502-9e34-e21ec2d38d77',
# ...

# %% [markdown]
# ### 서유럽 vs 하위권

# %%
SAsia=concat[concat['Region']=='South Asia']
SAsia=SAsia.pivot_table(index='Year',aggfunc='mean')
SAsia.reset_index(inplace=True)

SSAfrica=concat[concat['Region']=='Sub-Saharan Africa']
SSAfrica=SSAfrica.pivot_table(index='Year',aggfunc='mean')
SSAfrica.reset_index(inplace=True)

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity","Residual"))

for i in range(2):
    for j in range(3):
        if 3*i+j==6:
            break
        else:
            try:
                fig.add_trace(
                    go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(224,34,120)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(range=[0, 1.6],row=i+1, col=j+1)
                fig.add_trace(
                    go.Scatter(x=SAsia.loc[:,'Year'], y=SAsia.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(range=[0, 1.6],row=i+1, col=j+1)
                fig.add_trace(
                    go.Scatter(x=SSAfrica.loc[:,'Year'], y=SSAfrica.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(125,125,125)")),
                    row=i+1, col=j+1
                )
                fig.update_yaxes(range=[0, 1.6],row=i+1, col=j+1)
            except:
                pass
fig.add_trace(
    go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[5]],name='Western Europe',line=dict(color="rgb(224,34,120)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=SAsia.loc[:,'Year'], y=SAsia.loc[:,columns_to_look[5]],name='Low Rank Region',line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
    go.Scatter(x=SSAfrica.loc[:,'Year'], y=SSAfrica.loc[:,columns_to_look[5]],showlegend=False,line=dict(color="rgb(125,125,125)")),
    row=2, col=3
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.update_layout(title_text="Western vs Low Rank Region",width=1200,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dfd37ba0-dab5-4e21-814c-d3adc06b651f" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dfd37ba0-dab5-4e21-814c-d3adc06b651f")) {
#                     Plotly.newPlot(
#                         'dfd37ba0-dab5-4e21-814c-d3adc06b651f',
# ...

# %%
### Generosity는 크게 영향이 없어 보인다

# %% [markdown]
# ### 한국 vs 서유럽

# %%
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=("Economy","Social_support","Health","Freedom","Trust","Generosity"))

for i in range(2):
    for j in range(3):
        if 3*i+j==6:
            break
        else:
            try:
                fig.add_trace(
                    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(0,0,255)")),
                    row=i+1, col=j+1,
                )
                fig.update_yaxes(range=[0, 1.6],row=i+1, col=j+1)
                fig.add_trace(
                    go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[3*i+j]],showlegend=False,line=dict(color="rgb(224,34,120)")),
                    row=i+1, col=j+1,
                )
                fig.update_yaxes(range=[0, 1.6],row=i+1, col=j+1)
            except:
                pass

fig.add_trace(
    go.Scatter(x=Korea.loc[:,'Year'], y=Korea.loc[:,columns_to_look[5]],name='Korea',line=dict(color="rgb(0,0,255)")),
    row=2, col=3,
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)
fig.add_trace(
     go.Scatter(x=WEurope.loc[:,'Year'], y=WEurope.loc[:,columns_to_look[5]],name='Western Europe',line=dict(color="rgb(224,34,120)")),
     row=2, col=3,
)
fig.update_yaxes(range=[0, 1.6],row=2, col=3)

fig.update_layout(title_text="Korea vs Western Europe",width=1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eafcb1be-fe0a-4cfb-ac8e-ffcdebf3c988" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eafcb1be-fe0a-4cfb-ac8e-ffcdebf3c988")) {
#                     Plotly.newPlot(
#                         'eafcb1be-fe0a-4cfb-ac8e-ffcdebf3c988',
# ...

# %%
# 전체적으로 다 높음 그러나 Trust와 Freedom이 유난히 높음

# %%
##서유럽권이 정부에 대한 신뢰도가 많이 높음
